# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get("https://merolagani.com/LatestMarket.aspx")
soup = BeautifulSoup(r.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    merolagani - Nepal Stock Exchange (NEPSE) Live Trading Data, Live Floorsheet, Live Indices, Top Gainers, Top Losers
#   </title>
#   <link href="/bundles/css/main200?v=ybpqaBPOEhMITVP4ZJ82hCggvjB55v1k8y0JM95q2iY1" rel="stylesheet"/>
#   <link href="/bundles/css/site205?v=pzmPnkH2dtZvF-8iRn3l5kleBMIgUYDfmetvJFqXcbo1" rel="stylesheet"/>
#   <link href="/Content/Services.css" rel="stylesheet"/>
#   <link href="/Content/owl.carousel.min.css" rel="stylesheet"/>
#   <script src="/scripts/jquery/jquery-1.11.0.min.js">
#   </script>
#   <script src="/scripts/jquery/jquery-ui.js">
#   </script>
#   <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
# ...

# %%
result = soup.find(attrs={'class': 'table table-hover live-trading sortable'})

# %%
result.thead.decompose()

# %%
print(result.prettify())
# Out:
# <table class="table table-hover live-trading sortable" data-live="live-trading" data-live-label="#live-trading-label-1" width="100%">
#  <tbody>
#   <tr class="increase-row">
#    <td>
#     <a href="/CompanyDetail.aspx?symbol=ACLBSL" target="_blank" title="ACLBSL (Aarambha Chautari Laghubitta Bittiya Sanstha Limited)">
#      ACLBSL
#     </a>
#    </td>
#    <td class="text-right">
#     1,540.00
#    </td>
#    <td class="text-right">
#     10
#    </td>
#    <td class="text-right">
#     3.36
#    </td>
#    <td class="text-right">
#     1,540.00
#    </td>
#    <td class="text-right">
#     1,460.00
#    </td>
#    <td class="text-right">
#     1,470.00
#    </td>
#    <td class="text-right">
#     3,480
#    </td>
#    <td>
#     <a href="javascript:void(0);" onclick='addToWatchlist("ACLBSL");' title="Add to Watchlist">
#      <i class="icon-tags icon-white">
#      </i>
#     </a>
#    </td>
#    <td>
# ...

# %%
print(result.get_text(separator="\n", strip=True))
# Out:
# ACLBSL
# 1,540.00
# 10
# 3.36
# 1,540.00
# 1,460.00
# 1,470.00
# 3,480
# ADBL
# 426.00
# 15
# 0
# 434.00
# 421.00
# 421.00
# 41,639
# AHPC
# 357.00
# 10
# -3.51
# 388.00
# 355.00
# 388.00
# 398,461
# AIL
# 680.00
# 10
# -0.44
# 689.00
# 673.00
# 678.00
# 5,078
# AKJCL
# 143.00
# 10
# 0.7
# 147.00
# 141.00
# 142.00
# 7,464
# AKPL
# 320.00
# 10
# 0.95
# 324.00
# 317.00
# 319.00
# 52,766
# ALBSL
# 1,392.00
# 37
# -0.57
# 1,400.00
# 1,385.00
# 1,400.00
# 2,390
# ALICL
# 1,180.00
# 100
# -0.84
# 1,203.00
# 1,176.00
# 1,176.00
# 35,199
# API
# 300.00
# 50
# 3.45
# 308.00
# 276.00
# 276.00
# 314,328
# BARUN
# 236.00
# 20
# 0.43
# 241.00
# 232.00
# 233.00
# 6,980
# BFC
# 161.00
# 15
# 0.62
# 161.00
# 158.00
# 160.00
# 7,195
# BNT
# 9,019.00
# 10
# 6.29
# 9,019.00
# 8,328.00
# 8,328.00
# 265
# BOKL
# 306.00
# 903
# 0
# 308.00
# 302.00
# 308.00
# 54,907
# BPCL
# 392.00
# 47
# -0.51
# 399.00
# 392.00
# 394.00
# 14,977
# CBBL
# 1,509.00
# 20
# -2.08
# 1,615.00
# 1,500.00
# 1,615.00
# 38,005
# ...

# %%
whole = result.get_text(separator="\n", strip=True)

# %%
whole_list = whole.split('\n')

# %%
whole_list[:8]
# Out:
# ['ACLBSL',
#  '1,540.00',
#  '10',
#  '3.36',
#  '1,540.00',
#  '1,460.00',
#  '1,470.00',
#  '3,480']

# %%
whole_list[8:]
# Out:
# ['ADBL',
#  '426.00',
#  '15',
#  '0',
#  '434.00',
#  '421.00',
#  '421.00',
#  '41,639',
#  'AHPC',
#  '357.00',
#  '10',
#  '-3.51',
#  '388.00',
#  '355.00',
#  '388.00',
#  '398,461',
#  'AIL',
#  '680.00',
#  '10',
#  '-0.44',
#  '689.00',
#  '673.00',
#  '678.00',
#  '5,078',
#  'AKJCL',
#  '143.00',
#  '10',
#  '0.7',
#  '147.00',
#  '141.00',
#  '142.00',
#  '7,464',
#  'AKPL',
#  '320.00',
#  '10',
#  '0.95',
#  '324.00',
#  '317.00',
#  '319.00',
#  '52,766',
#  'ALBSL',
#  '1,392.00',
#  '37',
#  '-0.57',
#  '1,400.00',
#  '1,385.00',
#  '1,400.00',
#  '2,390',
#  'ALICL',
#  '1,180.00',
#  '100',
#  '-0.84',
#  '1,203.00',
#  '1,176.00',
#  '1,176.00',
#  '35,199',
#  'API',
#  '300.00',
#  '50',
#  '3.45',
#  '308.00',
#  '276.00',
#  '276.00',
#  '314,328',
#  'BARUN',
#  '236.00',
#  '20',
#  '0.43',
#  '241.00',
#  '232.00',
#  '233.00',
#  '6,980',
#  'BFC',
#  '161.00',
#  '15',
#  '0.62',
#  '161.00',
#  '158.00',
#  '160.00',
#  '7,195',
#  'BNT',
#  '9,019.00',
# ...

# %%
individual_list = []
for i in whole_list:
    temp = whole_list[:8]
    
    # converting string numerical values into float type
    for j in range(1,8):
        #print(temp[i])
        temp[j] = float(temp[j].replace(',', ''))
        #print(temp[i])
    print(temp)
    whole_list = whole_list[8:]
    individual_list.append(temp)
# Out:
# ['ACLBSL', 1540.0, 10.0, 3.36, 1540.0, 1460.0, 1470.0, 3480.0]
# ['ADBL', 426.0, 15.0, 0.0, 434.0, 421.0, 421.0, 41639.0]
# ['AHPC', 357.0, 10.0, -3.51, 388.0, 355.0, 388.0, 398461.0]
# ['AIL', 680.0, 10.0, -0.44, 689.0, 673.0, 678.0, 5078.0]
# ['AKJCL', 143.0, 10.0, 0.7, 147.0, 141.0, 142.0, 7464.0]
# ['AKPL', 320.0, 10.0, 0.95, 324.0, 317.0, 319.0, 52766.0]
# ['ALBSL', 1392.0, 37.0, -0.57, 1400.0, 1385.0, 1400.0, 2390.0]
# ['ALICL', 1180.0, 100.0, -0.84, 1203.0, 1176.0, 1176.0, 35199.0]
# ['API', 300.0, 50.0, 3.45, 308.0, 276.0, 276.0, 314328.0]
# ['BARUN', 236.0, 20.0, 0.43, 241.0, 232.0, 233.0, 6980.0]
# ['BFC', 161.0, 15.0, 0.62, 161.0, 158.0, 160.0, 7195.0]
# ['BNT', 9019.0, 10.0, 6.29, 9019.0, 8328.0, 8328.0, 265.0]
# ['BOKL', 306.0, 903.0, 0.0, 308.0, 302.0, 308.0, 54907.0]
# ['BPCL', 392.0, 47.0, -0.51, 399.0, 392.0, 394.0, 14977.0]
# ['CBBL', 1509.0, 20.0, -2.08, 1615.0, 1500.0, 1615.0, 38005.0]
# ['CBL', 225.0, 70.0, -0.88, 227.0, 224.0, 227.0, 67596.0]
# ...

# %%
individual_list
# Out:
# [['ACLBSL', 1540.0, 10.0, 3.36, 1540.0, 1460.0, 1470.0, 3480.0],
#  ['ADBL', 426.0, 15.0, 0.0, 434.0, 421.0, 421.0, 41639.0],
#  ['AHPC', 357.0, 10.0, -3.51, 388.0, 355.0, 388.0, 398461.0],
#  ['AIL', 680.0, 10.0, -0.44, 689.0, 673.0, 678.0, 5078.0],
#  ['AKJCL', 143.0, 10.0, 0.7, 147.0, 141.0, 142.0, 7464.0],
#  ['AKPL', 320.0, 10.0, 0.95, 324.0, 317.0, 319.0, 52766.0],
#  ['ALBSL', 1392.0, 37.0, -0.57, 1400.0, 1385.0, 1400.0, 2390.0],
#  ['ALICL', 1180.0, 100.0, -0.84, 1203.0, 1176.0, 1176.0, 35199.0],
#  ['API', 300.0, 50.0, 3.45, 308.0, 276.0, 276.0, 314328.0],
#  ['BARUN', 236.0, 20.0, 0.43, 241.0, 232.0, 233.0, 6980.0],
#  ['BFC', 161.0, 15.0, 0.62, 161.0, 158.0, 160.0, 7195.0],
#  ['BNT', 9019.0, 10.0, 6.29, 9019.0, 8328.0, 8328.0, 265.0],
#  ['BOKL', 306.0, 903.0, 0.0, 308.0, 302.0, 308.0, 54907.0],
#  ['BPCL', 392.0, 47.0, -0.51, 399.0, 392.0, 394.0, 14977.0],
#  ['CBBL', 1509.0, 20.0, -2.08, 1615.0, 1500.0, 1615.0, 38005.0],
# ...

# %%
import pymongo
mongodb_client = pymongo.MongoClient("mongodb+srv://susant:susant@cluster0.yevtz.mongodb.net/Merolagani?retryWrites=true&w=majority")

merolaganiDb = mongodb_client['Merolagani']
collection = merolaganiDb["test"]

for each in individual_list:
    print(each[0])
    data = {"Symbol": "each[0]","LTP":each[1], "LTV": each[2], "% Change": each[3], "High": each[4], "Low": each[5], "Open": each[6], "Qty": each[7]}
    collection.insert_one(data)
# Out:
# ACLBSL
# ADBL
# AHPC
# AIL
# AKJCL
# AKPL
# ALBSL
# ALICL
# API
# BARUN
# BFC
# BNT
# BOKL
# BPCL
# CBBL
# CBL
# CCBL
# CCBLPO
# CFCL
# CGH
# CHCL
# CHL
# CIT
# CLBSL
# CMF1
# CMF2
# CORBL
# CZBIL
# DDBL
# DHPL
# EBL
# EDBL
# EIC
# EICPO
# FMDBL
# FOWAD
# GBBL
# GBIME
# GBLBS
# GFCL
# GHL
# GIC
# GILB
# GIMES1
# GLBSL
# GLICL
# GMFBS
# GMFIL
# GRDBL
# GUFL
# HBL
# HDHPC
# HDL
# HGI
# HIDCL
# HPPL
# HURJA
# ICFC
# IGI
# ILBS
# JBBL
# JFL
# JOSHI
# JSLBB
# KBL
# KBLD86
# KKHC
# KLBSL
# KMCDB
# KPCL
# KRBL
# KSBBL
# LBBL
# LBL
# LEC
# LEMF
# LGIL
# LICN
# LLBS
# LUK
# MBL
# MDB
# MEGA
# MEN
# MERO
# MFIL
# MHNL
# MLBBL
# MLBL
# MMFDB
# MNBBL
# MPFL
# MSLB
# NABBC
# NABIL
# NBB
# NBBD2085
# NBF2
# NBL
# NCCB
# NEF
# NFS
# NGPL
# NHDL
# NHPC
# NIB
# NIBLPF
# NIBPO
# NIBSF1
# NICA
# NICAD8283
# NICBF
# NICGF
# NICL
# NIFRA
# NIL
# NLBBL
# NLG
# NLIC
# NLICL
# NMB
# NMB50
# NMBHF1
# NMBMF
# NMFBS
# NRIC
# NRN
# NTC
# NUBL
# OHL
# PBLD84
# PCBL
# PFL
# PIC
# PICL
# PLI
# PLIC
# PMHPL
# PPCL
# ...
